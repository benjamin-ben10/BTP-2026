# %%
# TO doooooooooo -> funcn names changed

# import sys
# sys.path.append("..")

# from src.channel import generate_irs_channels, channel_magnitude_stats

# model = generate_irs_channels(num_elements=1000, model="rayleigh", seed=42)

# print(model.h_bi.shape)
# print(model.h_iu.shape)
# print(model.cascaded.shape)

# print("BS-IRS stats:", channel_magnitude_stats(model.h_bi))
# print("IRS-User stats:", channel_magnitude_stats(model.h_iu))
# print("Cascaded stats:", channel_magnitude_stats(model.cascaded))
